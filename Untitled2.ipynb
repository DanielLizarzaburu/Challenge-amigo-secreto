# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielLizarzaburu/Challenge-amigo-secreto/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hola mundo")
# Out:
# Hola mundo
